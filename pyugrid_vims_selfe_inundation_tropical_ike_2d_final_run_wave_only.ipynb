# %%
from netCDF4 import Dataset
import matplotlib.pyplot as plt
import pyugrid
import matplotlib.tri as Tri
# %matplotlib inline
import numpy as np
import cartopy.crs as ccrs
url = "http://comt.sura.org/thredds/dodsC/data/comt_1_archive/inundation_tropical/VIMS_SELFE/Hurricane_Ike_2D_final_run_wave_only"

# %%
try:
    ug = pyugrid.UGrid.from_ncfile(url)
    lon = ug.nodes[:,0]
    lat = ug.nodes[:,1]
    nv  = ug.faces[:]
    triang = Tri.Triangulation(lon, lat, triangles=nv)
    print "is ugrid"
except:
    print "is not ugrid"
# Out:
# is ugrid

# %%
nc = Dataset(url,'r')
print nc.variables.keys()
# Out:
# [u'ele', u'x', u'y', u'depth', u'sigma', u'Cs', u'time', u'wwm_1', u'wwm_3', u'wwm_9', u'selfe_mesh', u'elev']

# %%
print nc.variables['elev'].shape
# Out:
# (384, 592761)

# %%
elev = nc.variables['elev']

# %%
elev

# %%
elev[:]
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-27-460e527d2f3d> in <module>()
# ----> 1 elev[:]
#
# /home/bmayer_local/.virtualenvs/wms/local/lib/python2.7/site-packages/netCDF4.so in netCDF4.Variable.__getitem__ (netCDF4.c:36122)()
#
# /home/bmayer_local/.virtualenvs/wms/local/lib/python2.7/site-packages/netCDF4.so in netCDF4.Variable._get (netCDF4.c:42860)()
#
# RuntimeError: NetCDF: Access failure

# %%
ax = plt.axes(projection=ccrs.PlateCarree())
ax.coastlines()
