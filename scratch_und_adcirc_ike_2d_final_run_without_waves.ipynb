# %%
from netCDF4 import Dataset
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import pyproj
import matplotlib.tri as Tri
import pyugrid
import numpy as np
import os
# %matplotlib inline

# %%
url="http://comt.sura.org/thredds/dodsC/data/comt_1_archive/inundation_tropical/UND_ADCIRC/Hurricane_Ike_2D_final_run_without_waves"

# %%
try:
    ug = pyugrid.UGrid.from_ncfile(url)
    lon = ug.nodes[:,0]
    lat = ug.nodes[:,1]
    nv = ug.faces[:]
    triang = Tri.Triangulation(lon, lat, triangles=nv)
    print "is ugrid"
except:
    print "is not ugrid"
# Out:
# is ugrid

# %%
print "{0}, {1}, {2}".format(lon.shape, lat.shape, nv.shape)
# Out:
# (417642,), (417642,), (826866, 3)

# %%
temp = os.path.realpath("./test.nc")
print temp
# Out:
# /home/bmayer_local/code/comt_testbed_notebooks/test.nc

# %%
ug.save_as_netcdf(temp)

# %%
try:
    ug2 = pyugrid.UGrid.from_ncfile(temp)
    lon2 = ug2.nodes[:,0]
    lat2 = ug2.nodes[:,1]
    nv2   = ug2.faces[:]
    print "Loaded"
except:
    print "Failed to load."
# Out:
# Loaded

# %%
lon2 = ug2.nodes[:,0]

# %%
lon2.shape
# Out:
# (417642,)

# %%
lon[:15]
# Out:
# array([-97.377766, -97.397618, -97.416182, -97.434252, -97.451839,
#        -97.468958, -97.485619, -97.501837, -97.517608, -97.532218,
#        -97.5456  , -97.558619, -97.57129 , -97.583623, -97.595627])

# %%
lon2[:15]
# Out:
# array([-97.377766, -97.397618, -97.416182, -97.434252, -97.451839,
#        -97.468958, -97.485619, -97.501837, -97.517608, -97.532218,
#        -97.5456  , -97.558619, -97.57129 , -97.583623, -97.595627])

# %%
triang = Tri.Triangulation(lon2, lat2, nv2)
plt.triplot(triang,'bo-')
